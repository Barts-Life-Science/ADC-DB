# %%
# %sql
INSERT INTO c_cold.raw.mill_ce_blob  
SELECT *  
FROM 4_prod.raw.mill_ce_blob  
WHERE CAST(ADC_UPDT AS TIMESTAMP) < (current_timestamp() - INTERVAL 30 DAYS);

# %%
# %sql
DELETE FROM 4_prod.raw.mill_ce_blob  
WHERE CAST(ADC_UPDT AS TIMESTAMP) < (current_timestamp() - INTERVAL 30 DAYS);
