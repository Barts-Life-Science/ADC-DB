# %%
# Updated copy: table and column metadata is applied by the local ./_common notebook.
# %run ./_common

# %%
# === CONFIG ===
TARGET = '5_projects.preborn'

# %%
rebuild_used_vocabulary_safely(TARGET)
print("PREBORN vocabulary finalized on", TARGET)
